# %% [markdown]
# # Querying population frequency using excel sheet as the input
# > The excel sheet should have column name of :
# >1. "Coordinate" for nucleotide position
# >2. "Chr" for Chromosomal number

# %%
import os, sqlite3, xlrd, time, datetime
import pandas as pd
from utils_query import *
import subprocess

# %% [markdown]
# ## 1. Creating sql table for the input

# %%
xls_file = pd.ExcelFile('query.xlsx')
table = xls_file.parse('All Samples')
chrom = [x for x in table['Chr'].unique()[:-1]]
conn = sqlite3.connect('dbase_Sqlite')
cleardb('dbase_Sqlite', 'dataFrame')
table.to_sql('dataFrame', conn)
# Out:
# /Users/leehongkai/anaconda/lib/python3.6/site-packages/pandas/core/generic.py:1345: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   chunksize=chunksize, dtype=dtype)

# %% [markdown]
# ## 2. Querying from Chinese, Malay and Indian populations

# %%
startTime = time.time()
query = """
        SELECT DISTINCT
            dataFrame.*, Indian_ALLELE_FREQ_1, Indian_ALLELE_FREQ_2, Indian.ID
        FROM
            dataFrame LEFT OUTER JOIN 
            Indian ON dataFrame.Coordinate=Indian.POS 
            AND dataFrame.Chr=Indian.CHROM
        """
df_I = pd.read_sql_query(query , conn)

query = """
        SELECT DISTINCT
            dataFrame.*, Malay_ALLELE_FREQ_1, Malay_ALLELE_FREQ_2, Malay.ID
        FROM
            dataFrame LEFT OUTER JOIN
            Malay ON dataFrame.Coordinate=Malay.POS
            AND dataFrame.Chr=Malay.CHROM
        """
df_M = pd.read_sql_query(query , conn)

query = """
        SELECT DISTINCT
            dataFrame.*, Chinese_ALLELE_FREQ_1, Chinese_ALLELE_FREQ_2, Chinese_ALLELE_FREQ_3, Chinese_ALLELE_FREQ_4, Chinese.ID
        FROM
            dataFrame LEFT OUTER JOIN
            Chinese ON dataFrame.Coordinate=Chinese.POS
            AND dataFrame.Chr=Chinese.CHROM
        """

df_C = pd.read_sql_query(query , conn)
        
timeTaken = time.time()-startTime 
print(datetime.datetime.now().strftime('%Y/%m/%d %H:%M:%S'), 
      '- Data Retrieval for all races completed: Took {} seconds to complete.'.format(timeTaken))
# Out:
# 2017/09/17 23:52:49 - Data Retrieval for all races completed: Took 334.83163189888 seconds to complete.

# %% [markdown]
# ## 3. Merging the output tables into one table

# %%
df = df_I.merge(df_C[['index','Chinese_ALLELE_FREQ_1','Chinese_ALLELE_FREQ_2','Chinese_ALLELE_FREQ_3', 'Chinese_ALLELE_FREQ_4']], 
                on=['index'], how='outer').merge(df_M[['index','Malay_ALLELE_FREQ_1', 'Malay_ALLELE_FREQ_2']], on=['index'], how='outer')
df[:9]
# Out:
#    index Sample   Gene Variant Chr  Coordinate  Variant Length Type Genotype  \
# 0      0  T1-MS   None   A>A/G   1    14804874               1  snv      het
# 1      1  T1-MS   SDHB   G>T/T   1    17380497               1  snv      hom
# 2      2  T1-MS  MUTYH   C>C/G   1    45797505               1  snv      het
# 3      3  T1-MS  MUTYH   C>C/G   1    45797505               1  snv      het
# 4      4  T1-MS   None   C>C/T   1   150860471               1  snv      het
# 5      5  T1-MS  NR5A2   A>A/G   1   200007432               1  snv      het
# 6      6  T1-MS   None   A>A/G   1   222164948               1  snv      het
# 7      7  T1-MS   None   G>G/T   2    15782471               1  snv      het
# 8      8  T1-MS    ALK   G>G/C   2    29416366               1  snv      het
#
#   Exonic         ...                 HGNC  Indian_ALLELE_FREQ_1  \
# 0     no         ...                 None                  None
# 1    yes         ...                 SDHB           G:0.0277778
# 2    yes         ...          MUTYH, HPDL            C:0.819444
# 3    yes         ...          MUTYH, HPDL            C:0.819444
# 4     no         ...                 None                  None
# 5     no         ...                NR5A2            A:0.541667
# 6     no         ...                 None                  None
# 7     no         ...                 None                  None
# 8    yes         ...                  ALK            G:0.430556
#
#    Indian_ALLELE_FREQ_2         ID Chinese_ALLELE_FREQ_1  \
# 0                  None       None                  None
# 1            T:0.972222  rs2746462                   G:0
# 2            G:0.180556  rs3219489             C:0.66129
# 3            G:0.180556  rs3219489             C:0.66129
# 4                  None       None                  None
# 5            G:0.458333  rs3790844            A:0.397849
# 6                  None       None                  None
# 7                  None       None                  None
# 8            C:0.569444  rs1881421            G:0.258065
#
#    Chinese_ALLELE_FREQ_2  Chinese_ALLELE_FREQ_3  Chinese_ALLELE_FREQ_4  \
# 0                   None                   None                   None
# 1                    T:1                   None                   None
# 2              G:0.33871                   None                   None
# 3              G:0.33871                   None                   None
# 4                   None                   None                   None
# 5             G:0.602151                   None                   None
# 6                   None                   None                   None
# 7                   None                   None                   None
# 8             C:0.741935                   None                   None
#
#   Malay_ALLELE_FREQ_1 Malay_ALLELE_FREQ_2
# 0                None                None
# 1                 G:0                 T:1
# 2          C:0.583333          G:0.416667
# 3          C:0.583333          G:0.416667
# 4                None                None
# 5          A:0.473958          G:0.526042
# 6                None                None
# 7                None                None
# 8          G:0.317708          C:0.682292
#
# [9 rows x 89 columns]

# %% [markdown]
# ## 4. Saving the output tables

# %%
df_I.to_excel("output_I.xls")
df_M.to_excel("output_M.xls")
df_C.to_excel("output_C.xls")
df.to_excel("output.xls")

# %%
query = """
        SELECT DISTINCT
            Malay.*
        FROM
            Malay
        WHERE POS in ('97816327', '14804874', '176637576', '150860471', '47601106')
        """

conn = sqlite3.connect('dbase_Sqlite')

df_testing = pd.read_sql_query(query , conn)
df_testing
# Out:
#    CHROM        POS  N_ALLELES  N_CHR Malay_ALLELE_FREQ_1 Malay_ALLELE_FREQ_2  \
# 0      2   47601106          2    192          T:0.192708          C:0.807292
# 1      2   97816327          2    174          T:0.965517         C:0.0344828
# 2      2   97816327          2    174          T:0.965517         C:0.0344828
# 3      2   97816327          2    174          T:0.965517         C:0.0344828
# 4      5  176637576          2    192          T:0.536458          C:0.463542
# 5      7   97816327          2    192          C:0.739583          T:0.260417
# 6      7   97816327          2    192          C:0.739583          T:0.260417
# 7      7   97816327          2    192          C:0.739583          T:0.260417
#
#            ID
# 0   rs1126497
# 1           .
# 2   rs6465657
# 3  rs77759206
# 4  rs28932178
# 5           .
# 6   rs6465657
# 7  rs77759206

# %%
df_try = df[:]
df_NullMalay = df[df["Malay_ALLELE_FREQ_1"].isnull()]

# %%
df_NullMalay_Chr1 = df_NullMalay[(df_NullMalay.Chr=='1')]
df_NullMalay_Chr1['Coordinate']
with open('query_Chr1.bed','w') as bedFile:
    for i in df_NullMalay_Chr1['Coordinate']:
        bedFile.write('chr1' + '\t' + str(i-1) + '\t' + str(i) + '\n')
with open('output.fa', "w") as outfile:
    proc = subprocess.Popen(['seqtk', 'subseq', '/Volumes/Samsung_T3/SgPopulationGenetics/GRCh37/chr1.fa', 'query_Chr1.bed'], 
                            stdin=subprocess.PIPE, stdout=outfile)
    out, err = proc.communicate()
p = open('output.fa', "r")

for i in df_NullMalay_Chr1['index']: 
    p.readline()
    df_try.loc[(df_try.index==i),('Malay_ALLELE_FREQ_1')] = str.capitalize(p.readline().replace('\n', ':1.0'))
df_try[:19]
# os.system('seqtk subseq /Volumes/Samsung_T3/SgPopulationGenetics/GRCh37/chr1.fa query_Chr1.bed > output.fa')
# Out:
#     index Sample   Gene Variant Chr  Coordinate  Variant Length Type Genotype  \
# 0       0  T1-MS   None   A>A/G   1    14804874               1  snv      het
# 1       1  T1-MS   SDHB   G>T/T   1    17380497               1  snv      hom
# 2       2  T1-MS  MUTYH   C>C/G   1    45797505               1  snv      het
# 3       3  T1-MS  MUTYH   C>C/G   1    45797505               1  snv      het
# 4       4  T1-MS   None   C>C/T   1   150860471               1  snv      het
# 5       5  T1-MS  NR5A2   A>A/G   1   200007432               1  snv      het
# 6       6  T1-MS   None   A>A/G   1   222164948               1  snv      het
# 7       7  T1-MS   None   G>G/T   2    15782471               1  snv      het
# 8       8  T1-MS    ALK   G>G/C   2    29416366               1  snv      het
# 9       9  T1-MS    ALK   T>T/C   2    29416481               1  snv      het
# 10     10  T1-MS    ALK   T>C/C   2    29416572               1  snv      hom
# 11     10  T1-MS    ALK   T>C/C   2    29416572               1  snv      hom
# 12     11  T1-MS    ALK   G>G/T   2    29445458               1  snv      het
# 13     12  T1-MS    ALK   G>G/A   2    29449820               1  snv      het
# 14     12  T1-MS    ALK   G>G/A   2    29449820               1  snv      het
# 15     13  T1-MS    ALK   A>A/G   2    29455267               1  snv      het
# 16     13  T1-MS    ALK   A>A/G   2    29455267               1  snv      het
# 17     14  T1-MS    ALK   T>C/C   2    29543663               1  snv      hom
# 18     15  T1-MS    ALK   A>T/T   2    29940529               1  snv      hom
#
#    Exonic         ...                 HGNC  Indian_ALLELE_FREQ_1  \
# 0      no         ...                 None                  None
# 1     yes         ...                 SDHB           G:0.0277778
# 2     yes         ...          MUTYH, HPDL            C:0.819444
# 3     yes         ...          MUTYH, HPDL            C:0.819444
# 4      no         ...                 None                  None
# 5      no         ...                NR5A2            A:0.541667
# 6      no         ...                 None                  None
# 7      no         ...                 None                  None
# 8     yes         ...                  ALK            G:0.430556
# 9     yes         ...                  ALK            T:0.430556
# 10    yes         ...                  ALK                   T:0
# 11    yes         ...                  ALK                   T:0
# 12    yes         ...                  ALK            G:0.430556
# 13    yes         ...                  ALK                  None
# 14    yes         ...                  ALK                  None
# 15    yes         ...                  ALK            A:0.555556
# 16    yes         ...                  ALK            A:0.555556
# 17    yes         ...                  ALK            T:0.194444
# 18    yes         ...                  ALK            A:0.388889
#
#     Indian_ALLELE_FREQ_2         ID Chinese_ALLELE_FREQ_1  \
# 0                   None       None                  None
# 1             T:0.972222  rs2746462                   G:0
# 2             G:0.180556  rs3219489             C:0.66129
# 3             G:0.180556  rs3219489             C:0.66129
# 4                   None       None                  None
# 5             G:0.458333  rs3790844            A:0.397849
# 6                   None       None                  None
# 7                   None       None                  None
# 8             C:0.569444  rs1881421            G:0.258065
# 9             C:0.569444  rs1881420            T:0.252688
# 10                   C:1  rs1670283                   T:0
# 11                   C:1  rs1670283                   T:0
# 12            T:0.569444  rs3795850            G:0.268817
# 13                  None       None            G:0.994624
# 14                  None       None            G:0.994624
# 15            G:0.444444  rs2256740            A:0.811828
# 16            G:0.444444  rs2256740            A:0.811828
# 17            C:0.805556  rs2293564           T:0.0752688
# 18            T:0.611111  rs2246745             A:0.22043
#
#     Chinese_ALLELE_FREQ_2  Chinese_ALLELE_FREQ_3  Chinese_ALLELE_FREQ_4  \
# 0                    None                   None                   None
# 1                     T:1                   None                   None
# 2               G:0.33871                   None                   None
# 3               G:0.33871                   None                   None
# 4                    None                   None                   None
# 5              G:0.602151                   None                   None
# 6                    None                   None                   None
# 7                    None                   None                   None
# 8              C:0.741935                   None                   None
# 9              C:0.747312                   None                   None
# 10                    C:1                   None                   None
# 11                    C:1                   None                   None
# 12             T:0.731183                   None                   None
# 13           A:0.00537634                   None                   None
# 14           A:0.00537634                   None                   None
# 15             G:0.188172                   None                   None
# 16             G:0.188172                   None                   None
# 17             C:0.924731                   None                   None
# 18              T:0.77957                   None                   None
#
#    Malay_ALLELE_FREQ_1 Malay_ALLELE_FREQ_2
# 0                A:1.0                None
# 1                  G:0                 T:1
# 2           C:0.583333          G:0.416667
# 3           C:0.583333          G:0.416667
# 4                C:1.0                None
# 5           A:0.473958          G:0.526042
# 6                A:1.0                None
# 7                 None                None
# 8           G:0.317708          C:0.682292
# 9             T:0.3125            C:0.6875
# 10                 T:0                 C:1
# 11                 T:0                 C:1
# 12          G:0.333333          T:0.666667
# 13          G:0.984375          A:0.015625
# 14          G:0.984375          A:0.015625
# 15          A:0.729167          G:0.270833
# 16          A:0.729167          G:0.270833
# 17          T:0.171875          C:0.828125
# 18           A:0.21875           T:0.78125
#
# [19 rows x 89 columns]
